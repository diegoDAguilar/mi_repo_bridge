# %% [markdown]
# # Ejercicios de Seaborn

# %%
# 1. Importa pandas, pyplot y seaborn

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 2. Activa matplotlib de forma estática

# %%
# %matplotlib inline

# %%
# 3. Lee 'Pokemon.csv', lee la primera columna del csv como índice del DataFrame

# %%
pokemon = pd.read_csv('./data/Pokemon.csv', encoding = 'ansi')

# %%
# 4. Mira las primeras filas del dataset para hacerte una idea de los datos cargados

# %%
pokemon.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     65      1      False
# 4     80      2      False

# %%
# 5. Haz un scatter plot con lmplot(), que es el método que pinta una regresión lineal
# Pasa el DataFrame como argumento del método en el parámetro llamado data

# %%
sns.lmplot(data=pokemon, x='Attack', y='Defense');

# %%
# 6. No queremos ver la línea recta de la regresión lineal.
# prueba a añadir fit_reg a falso

# %%
sns.lmplot(data=pokemon, x='Attack', y='Defense', fit_reg=False);

# %%
# 7. Vamos a decir qué variable (columna del DataFrame) codifica los colores (hue)
# Que el hue sea el Stage

# %%
sns.lmplot(data=pokemon, x='Attack', y='Defense', fit_reg=False, hue='Stage');

# %%
# 8. Limita el eje x entre 20 y 100

# %%
sns.lmplot(data=pokemon, x='Attack', y='Defense', fit_reg=False, hue='Stage');
plt.xlim(20,100);

# %%
# 9. Dibuja un diagrama de cajas con el dataframe

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data = pokemon)

# %%
# 10. No nos interesan las columnas Total, Stage ni Legendary
# Bórralos del DataFrame y vuelve a dibujar el diagrama de cajas

# %%
pokemon.drop(['Total', 'Stage', 'Legendary'], axis=1, inplace=True)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data = pokemon)

# %%
# 11. Mira cuántos 'Type 1' diferentes hay en el DataFrame

# %%
print(pokemon['Type 1'].nunique())
print(pokemon['Type 1'].unique())
# Out:
# 15
# ['Grass' 'Fire' 'Water' 'Bug' 'Normal' 'Poison' 'Electric' 'Ground'
#  'Fairy' 'Fighting' 'Psychic' 'Rock' 'Ghost' 'Ice' 'Dragon']

# %%
# 12. Quédate del Dataframe solo con los 'Type 1' iguales a 'Grass', 'Fire' o 'Water'

# %%
pokemon2 = pokemon[pokemon['Type 1'].isin(['Grass', 'Fire', 'Water'])].copy()

# %%
# 13. Usa un estilo 'whitegrid'

# %%
sns.set_style('whitegrid')

# %%
# 14. Pinta diagramas de violín con el DataFrame
sns.violinplot(data=pokemon2, x='Type 1', y='Attack', c=['g','r','b']);

# %%
pokemon2.dtypes
# Out:
# #           int64
# Name       object
# Type 1     object
# Type 2     object
# HP          int64
# Attack      int64
# Defense     int64
# Sp. Atk     int64
# Sp. Def     int64
# Speed       int64
# dtype: object

# %%
col_num = [c for c in pokemon2.columns if pokemon2[c].dtype == 'int64']
plt.figure(figsize=(14,6))
print(col_num)
for i,c in enumerate(col_num):
    plt.subplot(1,len(col_num),i+1)    
    sns.violinplot(pokemon2[c])
# Out:
# ['#', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']

# %%
# 15. Escribe una lista de colores con valores '#78C850', '#F08030',  '#6890F0'

# %%
colores = ['#78C850', '#F08030',  '#6890F0', 'b', 'b', 'b', 'b', 'b']

# %%
colores2 = ['#78C850', '#F08030',  '#6890F0']

# %%
# 16. Pinta de nuevo los diagramas de violín añadiendo esos colores en la paleta (palette)

# %%
col_num = [c for c in pokemon.columns if pokemon[c].dtype == 'int64']

# %%
pokemon2[pokemon2['Type 1'] == 'Grass']
# Out:
#        #        Name Type 1   Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1   Bulbasaur  Grass   Poison  45      49       49       65       65
# 1      2     Ivysaur  Grass   Poison  60      62       63       80       80
# 2      3    Venusaur  Grass   Poison  80      82       83      100      100
# 42    43      Oddish  Grass   Poison  45      50       55       75       65
# 43    44       Gloom  Grass   Poison  60      65       70       85       75
# 44    45   Vileplume  Grass   Poison  75      80       85      110       90
# 68    69  Bellsprout  Grass   Poison  50      75       35       70       30
# 69    70  Weepinbell  Grass   Poison  65      90       50       85       45
# 70    71  Victreebel  Grass   Poison  80     105       65      100       70
# 101  102   Exeggcute  Grass  Psychic  60      40       80       60       45
# 102  103   Exeggutor  Grass  Psychic  95      95       85      125       65
# 113  114     Tangela  Grass      NaN  65      55      115      100       40
#
#      Speed
# 0       45
# 1       60
# 2       80
# 42      30
# 43      40
# 44      50
# 68      40
# 69      55
# 70      70
# 101     40
# 102     55
# 113     60

# %%
sns.violinplot(pokemon2[pokemon2['Type 1'] == 'Grass']['Attack'])

# %%
# Busco cual es el pokemon de fuego tan fuerte
pokemon2[(pokemon2['Type 1'] == 'Fire')].sort_values('Attack')[::-1]
# Out:
#        #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 135  136     Flareon   Fire     NaN  65     130       60       95      110
# 58    59    Arcanine   Fire     NaN  90     110       80      100       80
# 145  146     Moltres   Fire  Flying  90     100       90      125       85
# 77    78    Rapidash   Fire     NaN  65     100       70       80       80
# 125  126      Magmar   Fire     NaN  65      95       57      100       85
# 76    77      Ponyta   Fire     NaN  50      85       55       65       65
# 5      6   Charizard   Fire  Flying  78      84       78      109       85
# 37    38   Ninetales   Fire     NaN  73      76       75       81      100
# 57    58   Growlithe   Fire     NaN  55      70       45       70       50
# 4      5  Charmeleon   Fire     NaN  58      64       58       80       65
# 3      4  Charmander   Fire     NaN  39      52       43       60       50
# 36    37      Vulpix   Fire     NaN  38      41       40       50       65
#
#      Speed
# 135     65
# 58      95
# 145     90
# 77     105
# 125     93
# 76      90
# 5      100
# 37     100
# 57      60
# 4       80
# 3       65
# 36      65

# %%
poke_types = ['Grass', 'Fire', 'Water']
plt.figure(figsize=(14,6))
for i,c in enumerate(poke_types):
    plt.subplot(1,len(colores2),i+1)    
    sns.violinplot(pokemon2[pokemon2['Type 1'] == poke_types[i]]['Attack'], color=colores2[i])
    plt.xlabel(poke_types[i])

# %%
col_num = [c for c in pokemon.columns if pokemon[c].dtype == 'int64']
plt.figure(figsize=(14,6))
print(col_num)
for i,c in enumerate(col_num):
    plt.subplot(1,len(col_num),i+1)    
    sns.violinplot(pokemon[c], color=colores[i])
# Out:
# ['#', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']

# %%
# 17. Con el diagrama de violín vemos la forma de la distribución, pero no sabemos si Grass tiene muchos puntos y Fire tiene muy pocos.
# Para ver esto, usamos el swarmplot.
# Pinta el último diagrama de violines pero con un swarmplot en lugar de un violin

# %%
#sns.violinplot(x=pokemon2['Type 1'], y=pokemon2['Attack'])
sns.swarmplot(x=pokemon2['Type 1'], y=pokemon2['Attack'])

# %%
col_num = [c for c in pokemon.columns if pokemon[c].dtype == 'int64']
plt.figure(figsize=(14,6))
print(col_num)
for i,c in enumerate(col_num):
    plt.subplot(1,len(col_num),i+1)    
    #sns.violinplot(pokemon[c], color=colores[i])
    sns.swarmplot(x=pokemon['Attack'], y=pokemon['Defense'],hue=pokemon[c], color=colores[i])
# Out:
# ['#', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']

# %%
# 18. Queremos ver los violines a la vez que los swarm, los podemos pintar juntos. 
# Elimina los diagramas de caja dentro de los violines con el parámetro inner = None y pon una transparencia de 0.9
# Pon un título con pyplot (como siempre)

# %%
plt.title('Diagrama de violines con swarmplot')
sns.violinplot(x=pokemon2['Type 1'], y=pokemon2['Attack'],inner=None)
sns.swarmplot(x=pokemon2['Type 1'], y=pokemon2['Attack']);

# %%
# 19. Veamos la función melt() de pandas. Melt toma los valores de varias columnas y los junta todos en una misma columna nueva.
# Dado un DataFrame, melt recibe varios parámetros:
# * qué columnas del DataFrame se quedan igual
# * qué nombres de columnas del dataframe pasan a ser una columna nueva
# * cómo queremos llamar esas nuevas columnas

# Primero recuerda el Dataframe df_grass_fire_water con las primeras 5 filas
pokemon2.head()

# %%
pokemon_3types = pokemon[pokemon['Type 1'].isin(['Grass', 'Fire', 'Water'])].copy()

# %%
pokemon3 = pokemon_3types.copy()
pokemon3.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     65      1      False
# 4     80      2      False

# %%
# 20. Queremos dejar igual las variables 'Name' y 'Type 1'
# Queremos añadir una columa nueva cuyos valores sean las columnas que queremos apilar y que se llame 'New Column'
# Escribimos df_grass_fire_water.melt(id_vars=['Name', 'Type 1'], value_vars=[...], var_name='New Column')

# %%
pokemon_melted = pokemon3.melt(id_vars=['Name','Type 1'],
              value_vars=['HP', 'Attack', 'Defense', 'Sp. Atk',
                         'Sp. Def', 'Speed', 'Stage']
              ,var_name='Melted')

# %%
# 21. Pintamos el swarmplot con el melted y entendemos la información

# %%
pokemon_melted[pokemon_melted.Name == 'Arcanine']
# Out:
#          Name Type 1   Melted  value
# 17   Arcanine   Fire       HP     90
# 69   Arcanine   Fire   Attack    110
# 121  Arcanine   Fire  Defense     80
# 173  Arcanine   Fire  Sp. Atk    100
# 225  Arcanine   Fire  Sp. Def     80
# 277  Arcanine   Fire    Speed     95
# 329  Arcanine   Fire    Stage      2

# %%
plt.figure(figsize=(10,6))
sns.swarmplot(data=pokemon_melted,x='Melted', y='value')
# Out:
# C:\Users\diego\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 75.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# 22. Basándote en el gráfico anterior, define el tamaño de la figura en (10,6) (usa plt)
# En el swarmplot añade el argumento dodge a True y usa la anterior paleta de colores Pokemon

# Dodge en inglés es "esquivar", ¿qué diferencia ves?

# Usando plt 
# fija el límite del eje Y entre 0 y 200
# fija la leyenda con bbox_to_anchor en upper left. Pista: upper left es el código 2 y se usa el parámetro loc.
plt.figure(figsize=(10,6))
sns.swarmplot(data=pokemon_melted,x='Melted',
              y='value',
             hue='Type 1',
              dodge = True,
             palette = colores2)
plt.ylim(0,200)
plt.legend(bbox_to_anchor=(1,1), loc=2)
# Out:
# C:\Users\diego\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\diego\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 75.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\diego\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 89.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# Observa que incluso usando Seaborn, usamos Pyplot para trabajar con los ejes, la leyenda y el tamaño
# Lo importante es que Seaborn y Pyplot conviven bien juntos

# %%
# 23. Mapas de calor
# Calcula las correlaciones del primer DataFrame original df
# Pista: las correlaciones se calculan con el método corr()
# Recuerda: las correlaciones miden entre dos variables, si varío una, cuánto me varía la otra (cómo están de relacionadas)

# %%
sns.__version__
# Out:
# '0.11.0'

# %%
import seaborn as sns

# %%
correlaciones = pokemon3.corr()

# %%
sns.heatmap(correlaciones, vmin=-1, vmax=1);

# %%
# ¿la correlación entre qué valores se encuentra?
# la autocorrelación es la correlación de una variable consigo misma, ¿qué aprecias?
# Encuentra dos variables que veas que están fuertemente relacionadas según la correlación
# Si tuvieras una matriz de correlación muy grande y te cobrasen por cada dato que lees, ¿qué harías?

# %%
# 24. Pinta el histograma y la densidad de probabilidad del nivel de defensa usando el DataFrame original

# %%
sns.distplot(pokemon3['Defense']);
# Out:
# C:\Users\diego\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#!pip install seaborn --upgrade
# Out:
# Collecting seaborn
#   Downloading seaborn-0.11.0-py3-none-any.whl (283 kB)
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in c:\users\diego\anaconda3\lib\site-packages (from seaborn) (1.18.5)
# Requirement already satisfied, skipping upgrade: scipy>=1.0 in c:\users\diego\anaconda3\lib\site-packages (from seaborn) (1.5.0)
# Requirement already satisfied, skipping upgrade: matplotlib>=2.2 in c:\users\diego\anaconda3\lib\site-packages (from seaborn) (3.2.2)
# Requirement already satisfied, skipping upgrade: pandas>=0.23 in c:\users\diego\anaconda3\lib\site-packages (from seaborn) (1.0.5)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in c:\users\diego\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\diego\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.2.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in c:\users\diego\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\diego\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\users\diego\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2020.1)
# Requirement already satisfied, skipping upgrade: six>=1.5 in c:\users\diego\anaconda3\lib\site-packages (from python-dateutil>=2.1->matplotlib>=2.2->seaborn) (1.15.0)
# Installing collected packages: seaborn
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.10.1
#     Uninstalling seaborn-0.10.1:
#       Successfully uninstalled seaborn-0.10.1
# Successfully installed seaborn-0.11.0

# %%
# 25. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original
# Usa un sns.countplot
# Usa plt.xticks y gira las etiquetas

# %%
sns.countplot(data=pokemon3,
             x = 'Type 1')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2]), <a list of 3 Text major ticklabel objects>)

# %%
# 26. Usa catplot con el DataFrame original. Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendarios
# y divide los colores según el Type 2

# %%
pokemon3[(pokemon3['Type 2'] == 'Ice')].sort_values('Defense')[::-1]
# Out:
#        #      Name Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 90    91  Cloyster  Water    Ice    525   50      95      180       85
# 130  131    Lapras  Water    Ice    535  130      85       80       85
# 86    87   Dewgong  Water    Ice    475   90      70       80       70
#
#      Sp. Def  Speed  Stage  Legendary
# 90        45     70      2      False
# 130       95     60      1      False
# 86        95     70      2      False

# %%
sns.catplot(data=pokemon3,
           x='Type 1',
           y = 'Defense',
           hue = 'Type 2');

# %%
# 27. Muestra una función distribución de probabilidad con kdeplot (curvas de nivel) de la defensa respecto al ataque.
# Di un bin 2D donde caigan muchos puntos (ataque, defensa).

# %%
sns.kdeplot(pokemon3['Attack'], pokemon3['Defense']);
# Out:
# C:\Users\diego\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# 29. Pinta una distribución de probabilidad conjunta, pintando la defensa respecto al ataque del DataFrame original
